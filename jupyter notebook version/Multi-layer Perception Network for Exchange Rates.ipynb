# %%
from prep import get_data

# %%
import prep

# %%
run prep

# %%
get_data(f='data/ec.csv', logme=lambda x:x)
# Out:
# (1507    Sep 21, 2014
#  1506    Sep 22, 2014
#  1505    Sep 23, 2014
#  1504    Sep 24, 2014
#  1503    Sep 25, 2014
#  1502    Sep 26, 2014
#  1501    Sep 28, 2014
#  1500    Sep 29, 2014
#  1499    Sep 30, 2014
#  1498    Oct 01, 2014
#  1497    Oct 02, 2014
#  1496    Oct 03, 2014
#  1495    Oct 05, 2014
#  1494    Oct 06, 2014
#  1493    Oct 07, 2014
#  1492    Oct 08, 2014
#  1491    Oct 09, 2014
#  1490    Oct 10, 2014
#  1489    Oct 12, 2014
#  1488    Oct 13, 2014
#  1487    Oct 14, 2014
#  1486    Oct 15, 2014
#  1485    Oct 16, 2014
#  1484    Oct 17, 2014
#  1483    Oct 19, 2014
#  1482    Oct 20, 2014
#  1481    Oct 21, 2014
#  1480    Oct 22, 2014
#  1479    Oct 23, 2014
#  1478    Oct 24, 2014
#              ...
#  29      Sep 09, 2019
#  28      Sep 10, 2019
#  27      Sep 11, 2019
#  26      Sep 12, 2019
#  25      Sep 13, 2019
#  24      Sep 16, 2019
#  23      Sep 17, 2019
#  22      Sep 18, 2019
#  21      Sep 19, 2019
#  20      Sep 20, 2019
# ...

# %%
from sys import exit

# %%
run train
# Out:
# Train size: 1206 Test size: 301 1508
# Epoch 1/30
#  - 0s - loss: 0.6562 - mse: 0.6562 - mape: 2.1962
# Epoch 2/30
#  - 0s - loss: 0.0320 - mse: 0.0320 - mape: 0.4394
# Epoch 3/30
#  - 0s - loss: 0.0262 - mse: 0.0262 - mape: 0.3544
# Epoch 4/30
#  - 0s - loss: 0.0258 - mse: 0.0258 - mape: 0.3449
# Epoch 5/30
#  - 0s - loss: 0.0259 - mse: 0.0259 - mape: 0.3475
# Epoch 6/30
#  - 0s - loss: 0.0260 - mse: 0.0260 - mape: 0.3486
# Epoch 7/30
#  - 0s - loss: 0.0259 - mse: 0.0259 - mape: 0.3472
# Epoch 8/30
#  - 0s - loss: 0.0259 - mse: 0.0259 - mape: 0.3437
# Epoch 9/30
#  - 0s - loss: 0.0259 - mse: 0.0259 - mape: 0.3470
# Epoch 10/30
#  - 0s - loss: 0.0258 - mse: 0.0258 - mape: 0.3469
# Epoch 11/30
#  - 0s - loss: 0.0259 - mse: 0.0259 - mape: 0.3490
# Epoch 12/30
#  - 0s - loss: 0.0259 - mse: 0.0259 - mape: 0.3456
# Epoch 13/30
#  - 0s - loss: 0.0259 - mse: 0.0259 - mape: 0.3456
# Epoch 14/30
#  - 0s - loss: 0.0260 - mse: 0.0260 - mape: 0.3498
# Epoch 15/30
# ...

# %%
run predict
# Out:
# Model loaded!
# Prediction from Oct 18, 2019 based on 34
# Prediction for Oct 18, 2019next is 34 +/- 1

# %%
from plot import plotme, plothist

# %%
help('modules')
