# %%
import C:\Users\blake\Documents\Future\Hands on Finance Projects\Exchange Rate Prediction\terminal version\prep
import C:\Users\blake\Documents\Future\Hands on Finance Projects\Exchange Rate Prediction\terminal version\train
# Out:
#   File "<ipython-input-7-2d851c04cbb7>", line 1
#     import C:\Users\blake\Documents\Future\Hands on Finance Projects\Exchange Rate Prediction\terminal version\prep
#             ^
# SyntaxError: invalid syntax

# %%
run prep
# Out:
#   File "C:\Users\blake\Documents\Future\Hands on Finance Projects\Exchange Rate Prediction\terminal version\prep.py", line 1
#     !/usr/bin/env python3
#     ^
# SyntaxError: invalid syntax

# %%
run train default 30 50
# Out:
# Train size: 1206 Test size: 301 1508
# Epoch 1/30
#  - 0s - loss: 831.2075 - mse: 831.2075 - mape: 99.9597
# Epoch 2/30
#  - 0s - loss: 829.7703 - mse: 829.7704 - mape: 99.8725
# Epoch 3/30
#  - 0s - loss: 828.3334 - mse: 828.3335 - mape: 99.7855
# Epoch 4/30
#  - 0s - loss: 826.8985 - mse: 826.8985 - mape: 99.6984
# Epoch 5/30
#  - 0s - loss: 825.4663 - mse: 825.4662 - mape: 99.6113
# Epoch 6/30
#  - 0s - loss: 824.0349 - mse: 824.0349 - mape: 99.5245
# Epoch 7/30
#  - 0s - loss: 822.6056 - mse: 822.6057 - mape: 99.4374
# Epoch 8/30
#  - 0s - loss: 821.1778 - mse: 821.1777 - mape: 99.3505
# Epoch 9/30
#  - 0s - loss: 819.7518 - mse: 819.7518 - mape: 99.2637
# Epoch 10/30
#  - 0s - loss: 818.3276 - mse: 818.3276 - mape: 99.1766
# Epoch 11/30
#  - 0s - loss: 816.9049 - mse: 816.9048 - mape: 99.0899
# Epoch 12/30
#  - 0s - loss: 815.4861 - mse: 815.4861 - mape: 99.0031
# Epoch 13/30
#  - 0s - loss: 814.0687 - mse: 814.0687 - mape: 98.9165
# Epoch 14/30
# ...

# %%
run predict default 50 34
# Out:
# Model loaded!
# Prediction from Oct 18, 2019 based on 34
# Prediction for Oct 18, 2019next is 2 +/- 0
